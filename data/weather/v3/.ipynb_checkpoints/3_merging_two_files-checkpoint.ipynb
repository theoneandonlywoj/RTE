# %%
import pandas as pd
import glob, os
from tqdm import tqdm
directory = "./2013/" 
os.chdir(directory)
#print(glob.glob("*csv"))

# %%
all_files = glob.glob("*csv")
len(all_files)
# Out:
# 8758

# %%
all_files[0]
# Out:
# 'P4503501.201306290800 .csv'

# %%
file1 = all_files[0] 
data1 = pd.read_csv(file1)
print(data1.columns)
data1 = data1.loc[data1.index[5]:data1.index[5]]
data1
# Out:
# Index(['Time', 'temperature-2', 'cloudiness-2', 'temperature-5',
#        'cloudiness-5', 'temperature-15', 'cloudiness-15', 'temperature-27',
#        'cloudiness-27', 'temperature-70', 'cloudiness-70', 'temperature-110',
#        'cloudiness-110', 'temperature-120', 'cloudiness-120',
#        'temperature-130', 'cloudiness-130', 'temperature-145',
#        'cloudiness-145', 'temperature-149', 'cloudiness-149',
#        'temperature-156', 'cloudiness-156', 'temperature-168',
#        'cloudiness-168', 'temperature-180', 'cloudiness-180',
#        'temperature-190', 'cloudiness-190', 'temperature-222',
#        'cloudiness-222', 'temperature-240', 'cloudiness-240',
#        'temperature-255', 'cloudiness-255', 'temperature-260',
#        'cloudiness-260', 'temperature-280', 'cloudiness-280',
#        'temperature-299', 'cloudiness-299', 'temperature-434',
#        'cloudiness-434', 'temperature-460', 'cloudiness-460',
#        'temperature-481', 'cloudiness-481', 'temperature-497',
#        'cloudiness-497', 'temperature-510', 'cloudiness-510',
#        'temperature-579', 'cloudiness-579', 'temperature-588',
#        'cloudiness-588', 'temperature-621', 'cloudiness-621',
#        'temperature-630', 'cloudiness-630', 'temperature-643',
#        'cloudiness-643', 'temperature-645', 'cloudiness-645',
#        'temperature-650', 'cloudiness-650', 'temperature-675',
#        'cloudiness-675', 'temperature-690', 'cloudiness-690',
#        'temperature-747', 'cloudiness-747'],
#       dtype='object')
#                   Time  temperature-2  cloudiness-2  temperature-5  \
# 5  2013-06-29 08:00:00           13.6             8           15.3
#
#    cloudiness-5  temperature-15  cloudiness-15  temperature-27  cloudiness-27  \
# 5             7            14.6              8            15.2              8
#
#    temperature-70       ...        temperature-645  cloudiness-645  \
# 5            16.1       ...                   22.4               1
#
#    temperature-650  cloudiness-650  temperature-675  cloudiness-675  \
# 5             22.8               0             22.7               0
#
#    temperature-690  cloudiness-690  temperature-747  cloudiness-747
# 5             21.8               1             22.3               1
#
# [1 rows x 71 columns]

# %%
file2 = all_files[1] 
data2 = pd.read_csv(file2)
data2 = data2.loc[data2.index[5]:data2.index[5]]
data2
# Out:
#                   Time  temperature-2  cloudiness-2  temperature-5  \
# 5  2013-10-06 23:00:00           12.8             0           10.7
#
#    cloudiness-5  temperature-15  cloudiness-15  temperature-27  cloudiness-27  \
# 5             0            10.7              1            10.1              0
#
#    temperature-70       ...        temperature-645  cloudiness-645  \
# 5            13.2       ...                   15.6               0
#
#    temperature-650  cloudiness-650  temperature-675  cloudiness-675  \
# 5             14.6               0             13.7               6
#
#    temperature-690  cloudiness-690  temperature-747  cloudiness-747
# 5             17.3               6             18.1               1
#
# [1 rows x 71 columns]

# %%
together = pd.concat([data1, data2])

# %%
together
# Out:
#                   Time  temperature-2  cloudiness-2  temperature-5  \
# 5  2013-06-29 08:00:00           13.6             8           15.3
# 5  2013-10-06 23:00:00           12.8             0           10.7
#
#    cloudiness-5  temperature-15  cloudiness-15  temperature-27  cloudiness-27  \
# 5             7            14.6              8            15.2              8
# 5             0            10.7              1            10.1              0
#
#    temperature-70       ...        temperature-645  cloudiness-645  \
# 5            16.1       ...                   22.4               1
# 5            13.2       ...                   15.6               0
#
#    temperature-650  cloudiness-650  temperature-675  cloudiness-675  \
# 5             22.8               0             22.7               0
# 5             14.6               0             13.7               6
#
#    temperature-690  cloudiness-690  temperature-747  cloudiness-747
# 5             21.8               1             22.3               1
# 5             17.3               6             18.1               1
#
# [2 rows x 71 columns]

# %%
together = pd.concat([together, data2])

# %%
together
# Out:
#                   Time  temperature-2  cloudiness-2  temperature-5  \
# 5  2013-06-29 08:00:00           13.6             8           15.3
# 5  2013-10-06 23:00:00           12.8             0           10.7
# 5  2013-10-06 23:00:00           12.8             0           10.7
#
#    cloudiness-5  temperature-15  cloudiness-15  temperature-27  cloudiness-27  \
# 5             7            14.6              8            15.2              8
# 5             0            10.7              1            10.1              0
# 5             0            10.7              1            10.1              0
#
#    temperature-70       ...        temperature-645  cloudiness-645  \
# 5            16.1       ...                   22.4               1
# 5            13.2       ...                   15.6               0
# 5            13.2       ...                   15.6               0
#
#    temperature-650  cloudiness-650  temperature-675  cloudiness-675  \
# 5             22.8               0             22.7               0
# 5             14.6               0             13.7               6
# 5             14.6               0             13.7               6
#
#    temperature-690  cloudiness-690  temperature-747  cloudiness-747
# 5             21.8               1             22.3               1
# 5             17.3               6             18.1               1
# 5             17.3               6             18.1               1
#
# [3 rows x 71 columns]

# %%
together.index = together['Time']

# %%
together.index
# Out:
# Index(['2013-06-29 08:00:00', '2013-10-06 23:00:00', '2013-10-06 23:00:00'], dtype='object', name='Time')
