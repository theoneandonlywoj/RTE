# %%
import pandas as pd
import numpy as np
import keras
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv('./data/weather/v3/2013/merged/merged_2013_h0.csv', index_col = 'Time')

# %%
data.head()
# Out:
#                      temperature-002  cloudiness-002  temperature-005  \
# Time
# 2013-01-01 00:00:00              9.3               8              8.5
# 2013-01-01 01:00:00              9.4               8              8.5
# 2013-01-01 02:00:00              9.7               8              8.2
# 2013-01-01 03:00:00              8.9               8              8.2
# 2013-01-01 04:00:00              9.5               7              8.6
#
#                      cloudiness-005  temperature-015  cloudiness-015  \
# Time
# 2013-01-01 00:00:00             8.0              8.3             8.0
# 2013-01-01 01:00:00             8.0              8.1             8.0
# 2013-01-01 02:00:00             8.0              8.2             8.0
# 2013-01-01 03:00:00             8.0              8.1             8.0
# 2013-01-01 04:00:00             8.0              8.2             8.0
#
#                      temperature-027  cloudiness-027  temperature-070  \
# Time
# ...
